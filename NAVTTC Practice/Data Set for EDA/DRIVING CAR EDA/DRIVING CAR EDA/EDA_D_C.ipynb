# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

#load dataset

self_dr_car=pd.read_csv('driving_log.csv')
self_dr_car=self_dr_car.sample(1000) #As our data cotains 8036 instances and 7 columns so that to analyze this data set i have take only sample of 1000 instances 

self_dr_car
# Out:
#                                       center  \
# 7416  IMG/center_2016_12_01_13_45_38_931.jpg
# 2782  IMG/center_2016_12_01_13_37_20_224.jpg
# 707   IMG/center_2016_12_01_13_33_49_906.jpg
# 2821  IMG/center_2016_12_01_13_37_24_180.jpg
# 4953  IMG/center_2016_12_01_13_41_29_174.jpg
# ...                                      ...
# 1257  IMG/center_2016_12_01_13_34_45_643.jpg
# 553   IMG/center_2016_12_01_13_33_34_260.jpg
# 7883  IMG/center_2016_12_01_13_46_26_346.jpg
# 7695  IMG/center_2016_12_01_13_46_07_213.jpg
# 4527  IMG/center_2016_12_01_13_40_45_980.jpg
#
#                                        left  \
# 7416   IMG/left_2016_12_01_13_45_38_931.jpg
# 2782   IMG/left_2016_12_01_13_37_20_224.jpg
# 707    IMG/left_2016_12_01_13_33_49_906.jpg
# 2821   IMG/left_2016_12_01_13_37_24_180.jpg
# 4953   IMG/left_2016_12_01_13_41_29_174.jpg
# ...                                     ...
# 1257   IMG/left_2016_12_01_13_34_45_643.jpg
# 553    IMG/left_2016_12_01_13_33_34_260.jpg
# 7883   IMG/left_2016_12_01_13_46_26_346.jpg
# 7695   IMG/left_2016_12_01_13_46_07_213.jpg
# 4527   IMG/left_2016_12_01_13_40_45_980.jpg
#
#                                        right  steering  throttle  brake  \
# 7416   IMG/right_2016_12_01_13_45_38_931.jpg  0.272268  0.985533    0.0
# 2782   IMG/right_2016_12_01_13_37_20_224.jpg  0.000000  0.985533    0.0
# 707    IMG/right_2016_12_01_13_33_49_906.jpg  0.000000  0.985533    0.0
# 2821   IMG/right_2016_12_01_13_37_24_180.jpg  0.000000  0.985533    0.0
# 4953   IMG/right_2016_12_01_13_41_29_174.jpg  0.000000  0.985533    0.0
# ...                                      ...       ...       ...    ...
# 1257   IMG/right_2016_12_01_13_34_45_643.jpg  0.000000  0.985533    0.0
# 553    IMG/right_2016_12_01_13_33_34_260.jpg -0.012285  0.985533    0.0
# 7883   IMG/right_2016_12_01_13_46_26_346.jpg -0.126218  0.639704    0.0
# 7695   IMG/right_2016_12_01_13_46_07_213.jpg -0.088240  0.985533    0.0
# 4527   IMG/right_2016_12_01_13_40_45_980.jpg  0.000000  0.985533    0.0
#
#          speed
# 7416  30.18008
# 2782  30.18625
# 707   30.18663
# 2821  30.18660
# 4953  30.18666
# ...        ...
# 1257  30.18667
# 553   30.18663
# 7883  30.09835
# 7695  30.18600
# 4527  11.11109
#
# [1000 rows x 7 columns]

# %%
# DATA_SHAPE
print(self_dr_car.shape)
rows,cols = self_dr_car.shape
print("Number of rows : ",rows) #instances 
print("Number of Cols: ",cols) #series
# Out:
# (1000, 7)
# Number of rows :  1000
# Number of Cols:  7

# %%
# DATA STRUCTURES

self_dr_car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 7416 to 4527
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   center    1000 non-null   object
#  1   left      1000 non-null   object
#  2   right     1000 non-null   object
#  3   steering  1000 non-null   float64
#  4   throttle  1000 non-null   float64
#  5   brake     1000 non-null   float64
#  6   speed     1000 non-null   float64
# dtypes: float64(4), object(3)
# memory usage: 62.5+ KB

# %%
# FINDING MISSING VALUES 
self_dr_car.isnull().sum()
# Out:
# center      0
# left        0
# right       0
# steering    0
# throttle    0
# brake       0
# speed       0
# dtype: int64

# %%
self_dr_car.describe()
# Out:
#           steering     throttle        brake        speed
# count  1000.000000  1000.000000  1000.000000  1000.000000
# mean      0.008400     0.863455     0.000538    27.957261
# std       0.135375     0.308485     0.012017     6.386558
# min      -0.809811     0.000000     0.000000     0.534007
# 25%       0.000000     0.985533     0.000000    30.181455
# 50%       0.000000     0.985533     0.000000    30.186315
# 75%       0.000000     0.985533     0.000000    30.186630
# max       0.731557     0.985533     0.268844    30.192300
